# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PassiveAggressiveRegressor

# %%
path ="/content/drive/MyDrive/dataset/Instagram data.csv"
df = pd.read_csv(path,encoding = 'latin1')
df.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
print(df.isnull().sum())
# Out:
# Impressions       0
# From Home         0
# From Hashtags     0
# From Explore      0
# From Other        0
# Saves             0
# Comments          0
# Shares            0
# Likes             0
# Profile Visits    0
# Follows           0
# Caption           0
# Hashtags          0
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB
# None

# %%
#lets analyse the distribution of impressions received from home

# %%
plt.figure(figsize=(8, 4))  # Adjust figure size if needed
plt.style.use('fivethirtyeight')
plt.hist(df['From Home'], bins=119, color='skyblue', edgecolor='black')
plt.title('Distribution of Impressions From Home')
plt.xlabel('Impressions From Home')
plt.ylabel('Frequency')
plt.show()

# %%
#the impressions we get from the home section on insta shows how much my posts reach my followers.
# from the results, we can say its hard o reach all the followers on the daily basis.

#further to inspect analysis throughly, lets have look at distribution of the impresiosns received from hashtags

# %%
plt.figure(figsize=(8,3))  # Adjust figure size if needed
plt.style.use('fivethirtyeight')
plt.hist(df['From Hashtags'], bins=100, color='skyblue', edgecolor='black')
plt.title('Distribution of Impressions From Hashtags')
# Out:
# Text(0.5, 1.0, 'Distribution of Impressions From Hashtags')

# %%
#Hashtags are tools we use to categorize our posts on Instagram so that we can reach more people based on the kind of content we are creating.
# Looking at hashtag impressions shows that not all posts can be reached using hashtags,
# but many new users can be reached from hashtags.

# %%
plt.figure(figsize=(8,3))
plt.style.use('fivethirtyeight')
plt.hist(df['From Explore'], bins=119, color='skyblue', edgecolor='black')
plt.title('Distribution of Impressions From Explore')
# Out:
# Text(0.5, 1.0, 'Distribution of Impressions From Explore')

# %%
#by the technical point of view, the explore section of the instagram is recommendation system of instagram.  it recommends post to user based on their prefereces and interest
#from the impressions we have received from explore section, we can say that the instagram does not recommend our posts to many users i.e the explore section recommendation engine has put some restrictions to some new uers
# but, the other part above scenario tells us that soome posts have received a good reach from the explore section. as compared to that of hastag it is still very low.

# %%
#lets find percentage of impresssions from various sources on instagram

# %%
home = data["From Home"].sum()
hastag = data["From Hashtags"].sum()
explore = data["From Explore"].sum()
other = data["From Other"].sum()

fig = px.py

# %%
home = df["From Home"].sum()
hashtag = df["From Hashtags"].sum()
explore = df["From Explore"].sum()
other = df["From Other"].sum()

labels = ['From Home', 'From Hashtags', 'From Explore', 'From Other']
values = [home, hashtag, explore, other]

fig = px.pie(names=labels, values=values, title='Percentage of Impressions from Various Sources',hole =0.5)


fig.show()
# Out:
#   File "<ipython-input-1-ad916b562ea8>", line 1
#     labels = ['Total Cases]
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
# from home user received 44% reach from followers, from hashtag user recived 34% rach, from explore user received 19% rech, from other section user received 3% reach.

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
text = " ".join(i for i in df.Caption)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords= stopwords, background_color="white").generate(text)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#lets create a world cloud of caption coloumn as its has more captions from instagrm post

# %%
text = " ".join(i for i in df.Hashtags)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
  #Analyzing Relationships

# %%
figure =px.scatter(data_frame=df,x="Impressions",y="Likes",size="Impressions",trendline="ols",title="Relationship Between Impressions and Likes")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure =px.scatter(data_frame=df,x="Impressions",y="Comments",size="Impressions",trendline="ols",title="Relationship Between Impressions and comments")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure =px.scatter(data_frame=df,y="Impressions",x="Comments",size="Impressions",trendline="ols",title="Relationship Between Impressions and comments")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure =px.scatter(data_frame=df,x="Impressions",y="Saves",size="Impressions",trendline="ols",title="Relationship Between Impressions and saves")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure =px.scatter(data_frame=df,x="Impressions",y="Shares",size="Impressions",trendline="ols",title="Relationship Between Impressions and shares")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure =px.scatter(data_frame=df,x="Impressions",y="Likes",size="Impressions",trendline="ols",title="Relationship Between Impressions and likes")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure =px.scatter(data_frame=df,x="Impressions",y="Profile Visits",size="Impressions",trendline="ols",title="Relationship Between Impressions and profile visits")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#analyzing conversion rate

# %%
conversion_rate = (df["Follows"].sum() / df["Profile Visits"].sum()) * 100
print(conversion_rate)
# Out:
# 41.00265604249668

# %%
figure =px.scatter(data_frame=df,y="Follows",x="Profile Visits",size="Impressions",trendline="ols",title="Relationship Between followers and profile visits")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#prediction

# %%
#instagram reach prediction model

# %%
x = np.array(df[['Likes', 'Saves', 'Comments', 'Shares',
                   'Profile Visits', 'Follows']])
y = np.array(df["Impressions"])
xtrain, xtest, ytrain, ytest = train_test_split(x, y,
                                                test_size=0.2,
                                                random_state=42)

# %%
model = PassiveAggressiveRegressor()
model.fit(xtrain, ytrain)
model.score(xtest, ytest)
# Out:
# 0.7675995897595433

# %%
#let’s predict the reach of an Instagram post by giving inputs to the machine learning model:

# %%
Features = [['Likes','Saves', 'Comments', 'Shares', 'Profile Visits', 'Follows']]
features = np.array([[282.0, 233.0, 4.0, 9.0, 165.0, 54.0]])
model.predict(features)
# Out:
# array([10045.7504806])
